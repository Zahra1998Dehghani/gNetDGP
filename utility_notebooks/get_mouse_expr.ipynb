# %%
import requests
import pandas as pd

# raw data from: https://tissues.jensenlab.org/Downloads
mouse_gene_expr = pd.read_csv("mouse_tissue_integrated_full.tsv", sep="\t", header=None)
mouse_gene_expr
# Out:
#                      0              1            2  \
# 0        0610012D04Rik  0610012D04Rik  BTO:0000000
# 1        0610012D04Rik  0610012D04Rik  BTO:0000042
# 2        0610012D04Rik  0610012D04Rik  BTO:0000887
# 3        0610012D04Rik  0610012D04Rik  BTO:0001103
# 4        0610012D04Rik  0610012D04Rik  BTO:0001369
# ...                ...            ...          ...
# 9040935       n-R5-8s1       n-R5-8s1  BTO:0003096
# 9040936       n-R5-8s1       n-R5-8s1  BTO:0000570
# 9040937       n-R5-8s1       n-R5-8s1  BTO:0000753
# 9040938       n-R5-8s1       n-R5-8s1  BTO:0001281
# 9040939       n-R5-8s1       n-R5-8s1  BTO:0005810
#
#                                               3      4
# 0        tissues, cell types and enzyme sources  0.515
# 1                                      Animalic  0.515
# 2                                        Muscle  0.515
# 3                               Skeletal muscle  0.515
# 4                    Vertebrate muscular system  0.515
# ...                                         ...    ...
# 9040935             Internal male genital organ  0.652
# 9040936                    Hematopoietic system  0.621
# 9040937                         Lymphoid tissue  0.621
# 9040938                                  Spleen  0.621
# 9040939                           Immune system  0.621
#
# [9040940 rows x 5 columns]

# %%
# take only the ENSMUS genes
mouse_gene_expr_ensemble = mouse_gene_expr[mouse_gene_expr.index >= 62786]
mouse_gene_expr_ensemble
# Out:
#                           0         1            2  \
# 62786    ENSMUSP00000000001     Gnai3  BTO:0000000
# 62787    ENSMUSP00000000001     Gnai3  BTO:0000042
# 62788    ENSMUSP00000000001     Gnai3  BTO:0001489
# 62789    ENSMUSP00000000001     Gnai3  BTO:0000522
# 62790    ENSMUSP00000000001     Gnai3  BTO:0001488
# ...                     ...       ...          ...
# 9040935            n-R5-8s1  n-R5-8s1  BTO:0003096
# 9040936            n-R5-8s1  n-R5-8s1  BTO:0000570
# 9040937            n-R5-8s1  n-R5-8s1  BTO:0000753
# 9040938            n-R5-8s1  n-R5-8s1  BTO:0001281
# 9040939            n-R5-8s1  n-R5-8s1  BTO:0005810
#
#                                               3      4
# 62786    tissues, cell types and enzyme sources  3.678
# 62787                                  Animalic  3.677
# 62788                                Whole body  3.677
# 62789                                     Gland  3.510
# 62790                           Endocrine gland  3.442
# ...                                         ...    ...
# 9040935             Internal male genital organ  0.652
# 9040936                    Hematopoietic system  0.621
# 9040937                         Lymphoid tissue  0.621
# 9040938                                  Spleen  0.621
# 9040939                           Immune system  0.621
#
# [8978154 rows x 5 columns]

# %%
mouse_gene_expr_ensemble.iloc[:, 0]
# Out:
# 62786      ENSMUSP00000000001
# 62787      ENSMUSP00000000001
# 62788      ENSMUSP00000000001
# 62789      ENSMUSP00000000001
# 62790      ENSMUSP00000000001
#                   ...
# 9040935              n-R5-8s1
# 9040936              n-R5-8s1
# 9040937              n-R5-8s1
# 9040938              n-R5-8s1
# 9040939              n-R5-8s1
# Name: 0, Length: 8978154, dtype: object

# %%
#mouse_gene_expr_ensemble["ENSMUSP" in mouse_gene_expr_ensemble.iloc[:, 0].values]
mouse_gene_expr_only_ensemble = mouse_gene_expr_ensemble[mouse_gene_expr_ensemble.iloc[:, 0].str.contains("ENSMUSP")]
mouse_gene_expr_only_ensemble
# Out:
#                           0      1            2  \
# 62786    ENSMUSP00000000001  Gnai3  BTO:0000000
# 62787    ENSMUSP00000000001  Gnai3  BTO:0000042
# 62788    ENSMUSP00000000001  Gnai3  BTO:0001489
# 62789    ENSMUSP00000000001  Gnai3  BTO:0000522
# 62790    ENSMUSP00000000001  Gnai3  BTO:0001488
# ...                     ...    ...          ...
# 8677541  ENSMUSP00000159257  Carlr  BTO:0000122
# 8677542  ENSMUSP00000159257  Carlr  BTO:0000138
# 8677543  ENSMUSP00000159257  Carlr  BTO:0000164
# 8677544  ENSMUSP00000159257  Carlr  BTO:0000901
# 8677545  ENSMUSP00000159257  Carlr  BTO:0000801
#
#                                               3      4
# 62786    tissues, cell types and enzyme sources  3.678
# 62787                                  Animalic  3.677
# 62788                                Whole body  3.677
# 62789                                     Gland  3.510
# 62790                           Endocrine gland  3.442
# ...                                         ...    ...
# 8677541                               Bile duct  0.507
# 8677542                                Midbrain  0.507
# 8677543                   Burkitt lymphoma cell  0.507
# 8677544                              Myocardium  0.506
# 8677545                              Macrophage  0.501
#
# [8614760 rows x 5 columns]

# %%
mouse_gene_expr_only_ensemble = mouse_gene_expr_only_ensemble.reset_index(drop=True)
mouse_gene_expr_only_ensemble
# Out:
#                           0      1            2  \
# 0        ENSMUSP00000000001  Gnai3  BTO:0000000
# 1        ENSMUSP00000000001  Gnai3  BTO:0000042
# 2        ENSMUSP00000000001  Gnai3  BTO:0001489
# 3        ENSMUSP00000000001  Gnai3  BTO:0000522
# 4        ENSMUSP00000000001  Gnai3  BTO:0001488
# ...                     ...    ...          ...
# 8614755  ENSMUSP00000159257  Carlr  BTO:0000122
# 8614756  ENSMUSP00000159257  Carlr  BTO:0000138
# 8614757  ENSMUSP00000159257  Carlr  BTO:0000164
# 8614758  ENSMUSP00000159257  Carlr  BTO:0000901
# 8614759  ENSMUSP00000159257  Carlr  BTO:0000801
#
#                                               3      4
# 0        tissues, cell types and enzyme sources  3.678
# 1                                      Animalic  3.677
# 2                                    Whole body  3.677
# 3                                         Gland  3.510
# 4                               Endocrine gland  3.442
# ...                                         ...    ...
# 8614755                               Bile duct  0.507
# 8614756                                Midbrain  0.507
# 8614757                   Burkitt lymphoma cell  0.507
# 8614758                              Myocardium  0.506
# 8614759                              Macrophage  0.501
#
# [8614760 rows x 5 columns]

# %%
#mouse_gene_expr_only_ensemble.to_csv("mouse_ensemble_gene_expression_TISSUES.tsv", sep="\t", index=None)

# %%
gene_names = mouse_gene_expr_only_ensemble.iloc[:, 1].tolist()
unique_mouse_genes = list(set(gene_names))
len(unique_mouse_genes)
# Out:
# 20880

# %%
unique_mouse_genes[:10]
# Out:
# ['Fbxo41',
#  'Sap30l',
#  'Npy5r',
#  'Ppp5c',
#  'Mgrn1',
#  'Col7a1',
#  'Olfr1246',
#  'Rbm4b',
#  'Dicer1',
#  'Sypl2']

# %%
human_genes = pd.read_csv("df_human_genes_data_NCBI.tsv", sep="\t")
human_genes
# Out:
#               Symbol     GeneID
# 0               APOE        348
# 1                ACE       1636
# 2              HLA-B       3106
# 3            CYP19A1       1588
# 4             UGT1A1      54658
# ...              ...        ...
# 193499  LOC128966549  128966549
# 193500    TRN-GTT3-2  116652394
# 193501    TRP-AGG3-1  100189361
# 193502    TRW-CCA6-1  100189309
# 193503    TRY-GTA9-1  100189057
#
# [193504 rows x 2 columns]

# %%
mouse_gene_names = list()
mouse_human_gene_names = list()
human_ortholog_entrez_gene_ids = list()
mouse_genes_not_present = list()

print("Filtering {} mouse genes".format(len(unique_mouse_genes)))

for mouse_gene in unique_mouse_genes:
    u_gene = mouse_gene.upper()
    m_human_ortho_gene_id = human_genes[human_genes["Symbol"] == u_gene]
    if len(m_human_ortho_gene_id.index) > 0:
        mouse_gene_names.append(mouse_gene)
        mouse_human_gene_names.append(u_gene)
        human_ortholog_entrez_gene_ids.append(int(m_human_ortho_gene_id["GeneID"].values[0]))
    else:
        mouse_genes_not_present.append(mouse_gene)
    
df_mouse_human_gene_ids_list = pd.DataFrame(zip(mouse_gene_names, mouse_human_gene_names, human_ortholog_entrez_gene_ids), \
                                            columns=["MouseGene", "HumanGene", "HumanOrthologEntrezID"])
# Out:
# Filtering 20880 mouse genes

# %%
df_mouse_human_gene_ids_list
# Out:
#       MouseGene HumanGene  HumanOrthologEntrezID
# 0        Fbxo41    FBXO41                 150726
# 1        Sap30l    SAP30L                  79685
# 2         Npy5r     NPY5R                   4889
# 3         Ppp5c     PPP5C                   5536
# 4         Mgrn1     MGRN1                  23295
# ...         ...       ...                    ...
# 15887      Bag1      BAG1                    573
# 15888    Slc6a5    SLC6A5                   9152
# 15889     Foxe1     FOXE1                   2304
# 15890     Krt20     KRT20                  54474
# 15891    Adam23    ADAM23                   8745
#
# [15892 rows x 3 columns]

# %%
df_mouse_human_gene_ids_list.to_csv("df_mouse_human_gene_ids_list.tsv", index=None)

# %%
len(mouse_genes_not_present)
# Out:
# 4988

# %%
mouse_gene_expr_only_ensemble
# Out:
#                           0      1            2  \
# 0        ENSMUSP00000000001  Gnai3  BTO:0000000
# 1        ENSMUSP00000000001  Gnai3  BTO:0000042
# 2        ENSMUSP00000000001  Gnai3  BTO:0001489
# 3        ENSMUSP00000000001  Gnai3  BTO:0000522
# 4        ENSMUSP00000000001  Gnai3  BTO:0001488
# ...                     ...    ...          ...
# 8614755  ENSMUSP00000159257  Carlr  BTO:0000122
# 8614756  ENSMUSP00000159257  Carlr  BTO:0000138
# 8614757  ENSMUSP00000159257  Carlr  BTO:0000164
# 8614758  ENSMUSP00000159257  Carlr  BTO:0000901
# 8614759  ENSMUSP00000159257  Carlr  BTO:0000801
#
#                                               3      4
# 0        tissues, cell types and enzyme sources  3.678
# 1                                      Animalic  3.677
# 2                                    Whole body  3.677
# 3                                         Gland  3.510
# 4                               Endocrine gland  3.442
# ...                                         ...    ...
# 8614755                               Bile duct  0.507
# 8614756                                Midbrain  0.507
# 8614757                   Burkitt lymphoma cell  0.507
# 8614758                              Myocardium  0.506
# 8614759                              Macrophage  0.501
#
# [8614760 rows x 5 columns]

# %%
mouse_gene_expr_only_ensemble.to_csv("mouse_gene_expr_only_ensemble.tsv", index=None)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 mouse_gene_expression_genes = mouse_gene_expr_only_ensemble
# ----> 2 mouse_gene_expression_genes.loc[:, 5] = mouse_gene_ids
#       3 mouse_gene_expression_genes
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1728, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1725 # add a new item with the dtype setup
#    1726 if com.is_null_slice(indexer[0]):
#    1727     # We are setting an entire column
# -> 1728     self.obj[key] = value
#    1729     return
#    1730 elif is_array_like(value):
#    1731     # GH#42099
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (1001) does not match length of index (8614760)
